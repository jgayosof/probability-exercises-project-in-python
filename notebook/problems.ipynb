# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import numpy as np
from random import *

repeat = 1000

#Funtion to roll the dice.
def roll_2_dices(repeat) :
    positive_cases = 0
    for i in range(repeat) :
        dice1 = randint(1,6)
        dice2 = randint(1,6)
        if ( (dice1 + dice2) > 7 or (dice1 + dice2) % 2 == 0 ) :
            positive_cases +=1
    return (positive_cases)

prob = roll_2_dices(repeat)/repeat
print(prob)
# Out:
# 0.655

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries
import numpy as np
from random import *
import itertools as it

d = {}
for i in range(60):
    if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'  
        
#Initialize important variables
n_simulations = 50000
positive_cases1 = 0
positive_cases2 = 0

for i in range(n_simulations):
    whites = 0
    reds = 0
    greens = 0
    dict_aux = {}
    # Pick 5 balls randomly:
    for j in range(5) :
        random_pick = randint(0,len(d)-1)
        dict_aux[j] = d[random_pick]
        if dict_aux[j] == 'White' :
            whites += 1
            #print('whites:', whites)
        elif dict_aux[j] == 'Red' :
            reds += 1
            #print('reds:', reds)
        else :
            greens += 1
    if (whites == 3 or reds == 2) :
        positive_cases1 += 1
    if ( whites==5 or reds==5 or greens==5 ) :
        positive_cases2 += 1

prob1 = 100*positive_cases1/n_simulations
print('The probability of taking 3 reds or 2 whites is: ' + str(prob1) + ' %')

prob2 = 100*positive_cases2/n_simulations
print('The probability of taking 5 balls with the same color is: ' + str(prob2) + ' %')

    #make a list of the colors that we choose
    #Convert it to a numpy array
    #find the number of each taht we picked  
    #Keep track if the combination met the criteria
#print 'the probability of 3 white and 2 red is' in percentage
#print 'the probability of all the same color is' in percentage
# Out:
# The probability of taking 3 reds or 2 whites is: 35.598 %
# The probability of taking 5 balls with the same color is: 3.558 %
